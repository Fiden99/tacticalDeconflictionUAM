# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Read the data
# ### Read "normal" data

# %%
pdDD = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdAP = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdNC = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/30_heurMercedes_DD_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdDD = pd.concat([pdDD, temp], ignore_index=True)

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/30_heurMercedes_AP_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdAP = pd.concat([pdAP, temp], ignore_index=True)


for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/30_heurMercedes_NC_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdNC = pd.concat([pdNC, temp], ignore_index=True)

        pdDD = pdDD.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdAP = pdAP.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdNC = pdNC.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')

# %% [markdown]
# ### read greater

# %%
pdDD_Greater = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdAP_Greater = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdNC_Greater = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Greater_heurMercedes_DD_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdDD_Greater = pd.concat([pdDD_Greater, temp], ignore_index=True)

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Greater_heurMercedes_AP_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdAP_Greater = pd.concat([pdAP_Greater, temp], ignore_index=True)


for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Greater_heurMercedes_NC_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdNC_Greater = pd.concat([pdNC_Greater, temp], ignore_index=True)

        pdDD_Greater = pdDD_Greater.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdAP_Greater = pdAP_Greater.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdNC_Greater = pdNC_Greater.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')

# %% [markdown]
# ### Read Smaller

# %%
pdDD_Smaller = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdAP_Smaller = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})
pdNC_Smaller = pd.DataFrame({
    'instance': pd.Series(dtype='string'),
    'timelimit': pd.Series(dtype='int'),
    'opt': pd.Series(dtype='float'),
    'totalTime': pd.Series(dtype='float'),
    'bestTime': pd.Series(dtype='float'),
    'nIter': pd.Series(dtype='int'),
    'optIter': pd.Series(dtype='int'),
    'alpha' : pd.Series(dtype='int'),
    'gapUnf': pd.Series(dtype='int'),
})

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Smaller_heurMercedes_DD_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdDD_Smaller = pd.concat([pdDD_Smaller, temp], ignore_index=True)

for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Smaller_heurMercedes_AP_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdAP_Smaller = pd.concat([pdAP_Smaller, temp], ignore_index=True)


for i in [4, 9, 16, 25, 100]:
    for j in [1, 2, 5, 10]:
        temp = pd.read_csv(f'/home/magi/UAMdeconflictionMasterThesis/modelli/results/afterMasterThesis/30_Smaller_heurMercedes_NC_{i}_{j}.csv',header=None, names= ['instance', 'timelimit', 'opt', 'totalTime', 'bestTime', 'nIter', 'optIter'])
        temp['alpha'] = i
        temp['gapUnf'] = j
        pdNC_Smaller = pd.concat([pdNC_Smaller, temp], ignore_index=True)

        pdDD_Smaller = pdDD_Smaller.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdAP_Smaller = pdAP_Smaller.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')
        pdNC_Smaller = pdNC_Smaller.drop_duplicates(subset=['instance', 'alpha', 'gapUnf'], keep='last')

# %% [markdown]
# ### Write all readed data in latex

# %%
#DD
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesDD_Greater.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdDD_Greater.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesDD_Smaller.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdDD_Smaller.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesDD.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdDD.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

#AP
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesAP_Greater.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdAP_Greater.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesAP_Smaller.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdAP_Smaller.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesAP.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdAP.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

#NC
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesNC_Greater.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdNC_Greater.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesNC_Smaller.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdNC_Smaller.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/latex/TimesNC.tex", "w") as f:
    f.write("\\begin{document}\n")
    f.write(pdNC.to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|r|r|"))
    f.write("\\end{document}")

# %% [markdown]
# ## Creation of sub-dataframe
#
# ### drift and delay

# %%
#airport
#airport01
df_G_air01 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"airport\d+nDr0nDe1")]
df_S_air01 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"airport\d+nDr0nDe1")]
df_air01 = pdDD[pdDD['instance'].str.contains(r"airport\d+nDr0nDe1")]
#airport02
df_G_air02 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"airport\d+nDr0nDe2")]
df_S_air02 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"airport\d+nDr0nDe2")]
df_air02 = pdDD[pdDD['instance'].str.contains(r"airport\d+nDr0nDe2")]
#airport3
df_G_air03 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"airport\d+nDr0nDe3")]
df_S_air03 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"airport\d+nDr0nDe3")]
df_air03 = pdDD[pdDD['instance'].str.contains(r"airport\d+nDr0nDe3")]

#grid
#grid01
df_G_grid01 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"grid\d+nDr0nDe1")]
df_S_grid01 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"grid\d+nDr0nDe1")]
df_grid01 = pdDD[pdDD['instance'].str.contains(r"grid\d+nDr0nDe1")]
#grid02
df_G_grid02 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"grid\d+nDr0nDe2")]
df_S_grid02 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"grid\d+nDr0nDe2")]
df_grid02 = pdDD[pdDD['instance'].str.contains(r"grid\d+nDr0nDe2")]
#grid3
df_G_grid03 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"grid\d+nDr0nDe3")]
df_S_grid03 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"grid\d+nDr0nDe3")]
df_grid03 = pdDD[pdDD['instance'].str.contains(r"grid\d+nDr0nDe3")]

#metroplex
#metroplex01
df_G_mp01 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"metroplex\d+nDr0nDe1")]
df_S_mp01 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"metroplex\d+nDr0nDe1")]
df_mp01 = pdDD[pdDD['instance'].str.contains(r"metroplex\d+nDr0nDe1")]
#metroplex02
df_G_mp02 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"metroplex\d+nDr0nDe2")]
df_S_mp02 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"metroplex\d+nDr0nDe2")]
df_mp02 = pdDD[pdDD['instance'].str.contains(r"metroplex\d+nDr0nDe2")]
#metroplex3
df_G_mp03 = pdDD_Greater[pdDD_Greater['instance'].str.contains(r"metroplex\d+nDr0nDe3")]
df_S_mp03 = pdDD_Smaller[pdDD_Smaller['instance'].str.contains(r"metroplex\d+nDr0nDe3")]
df_mp03 = pdDD[pdDD['instance'].str.contains(r"metroplex\d+nDr0nDe3")]

# %% [markdown]
# ### AP and NC

# %%
#AP
#airport AP
df_G_airAP = pdAP_Greater[pdAP_Greater['instance'].str.contains(r"airport")]
df_S_airAP = pdAP_Smaller[pdAP_Smaller['instance'].str.contains(r"airport")]
df_airAP = pdAP[pdAP['instance'].str.contains(r"airport")]
#grid AP
df_G_gridAP = pdAP_Greater[pdAP_Greater['instance'].str.contains(r"grid")]
df_S_gridAP = pdAP_Smaller[pdAP_Smaller['instance'].str.contains(r"grid")]
df_gridAP = pdAP[pdAP['instance'].str.contains(r"grid")]
#metroplex AP
df_G_mpAP = pdAP_Greater[pdAP_Greater['instance'].str.contains(r"metroplex")]
df_S_mpAP = pdAP_Smaller[pdAP_Smaller['instance'].str.contains(r"metroplex")]
df_mpAP = pdAP[pdAP['instance'].str.contains(r"metroplex")]

#NC
#airport NC
df_G_airNC = pdNC_Greater[pdNC_Greater['instance'].str.contains(r"airport")]
df_S_airNC = pdNC_Smaller[pdNC_Smaller['instance'].str.contains(r"airport")]
df_airNC = pdNC[pdNC['instance'].str.contains(r"airport")]
#grid NC
df_G_gridNC = pdNC_Greater[pdNC_Greater['instance'].str.contains(r"grid")]
df_S_gridNC = pdNC_Smaller[pdNC_Smaller['instance'].str.contains(r"grid")]
df_gridNC = pdNC[pdNC['instance'].str.contains(r"grid")]
#metroplex NC
df_G_mpNC = pdNC_Greater[pdNC_Greater['instance'].str.contains(r"metroplex")]
df_S_mpNC = pdNC_Smaller[pdNC_Smaller['instance'].str.contains(r"metroplex")]
df_mpNC = pdNC[pdNC['instance'].str.contains(r"metroplex")]

# %% [markdown]
# ### functions to obtain various data

# %%
def get_formatted_name(data_name,AP=False,NC=False, alpha=None, gapUnf=None):
    data_name = data_name.replace("Fixed", "")
    match = re.match(r"([a-zA-Z]+)(\d+)([a-zA-Z0-9-]*)", data_name)
    if match:
        part1 = match.group(1)
        part2 = match.group(3)
        part3 = ""
        part4 = ""
        if AP:
            part3 = "AP"
        elif NC:
            part3 = "NC"        
        if alpha is not None and gapUnf is not None:
            part4 = f"Alpha{alpha}Gap{gapUnf}"
        return f"{part1}{part2}{part3}{part4}"
    else:
        return data_name  # Caso in cui non ci sia un numero nel nome

# %%
def obtainStatsSummary(filtered_merged, columnName, AP=False, NC=False):
    results = []
    grouped = filtered_merged.groupby(["alpha", "gapUnf"])
    for (alpha, gapUnf), group in grouped:
        finite_values = group[np.isfinite(group[columnName])][columnName]
        stats = {
            "Typology":         get_formatted_name(filtered_merged["instance"].iloc[0],AP,NC,alpha,gapUnf),
            "Mean":             finite_values.mean(),
            "STD":              finite_values.std(),
            "Min":              finite_values.min(),
            "Max":              finite_values.max(),
            "CountSolved":      finite_values.count(),
            "TotalCount":       group[columnName].count()
        }
        results.append(stats)
    return results

# %%
dfs     = [df_air01,df_air02,df_air03,df_grid01,df_grid02,df_grid03,df_mp01,df_mp02,df_mp03]
dfs_G   = [df_G_air01,df_G_air02,df_G_air03,df_G_grid01,df_G_grid02,df_G_grid03,df_G_mp01,df_G_mp02,df_G_mp03]
dfs_S   = [df_S_air01,df_S_air02,df_S_air03,df_S_grid01,df_S_grid02,df_S_grid03,df_S_mp01,df_S_mp02,df_S_mp03]
dfsAP   = [df_airAP,df_gridAP,df_mpAP]
dfsAP_G = [df_G_airAP,df_G_gridAP,df_G_mpAP]
dfsAP_S = [df_S_airAP,df_S_gridAP,df_S_mpAP]
dfsNC   = [df_airNC,df_gridNC,df_mpNC]
dfsNC_G = [df_G_airNC,df_G_gridNC,df_G_mpNC]
dfsNC_S = [df_S_airNC,df_S_gridNC,df_S_mpNC]

# %% [markdown]
# ## Write the files

# %%
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/times/SummaryTables.tex", "w") as f:
    f.write("\\begin{document}\n")

    #prima tabella: opt
    
    results = []
    for i, df in enumerate(dfs):
        #def obtainStatsSummary(filtered_merged, columnName, AP=False, NC=False):
        for stats in obtainStatsSummary(df, "opt"):
            results.append(stats)
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "opt",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC):
        for stats in obtainStatsSummary(df, "opt",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:results",caption="Statistics about \\textbf{objective function value} obtained from heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #seconda tabella: totalTime

    results = []
    for i, df in enumerate(dfs):
        for stats in obtainStatsSummary(df, "totalTime"):   
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "totalTime",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC):
        for stats in obtainStatsSummary(df, "totalTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:totalTime",caption="Statistic about \\textbf{total Time} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #terza tabella: bestTime
    results = []
    for i, df in enumerate(dfs):
        for stats in obtainStatsSummary(df, "bestTime"):
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "bestTime",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC):
        for stats in obtainStatsSummary(df, "bestTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:bestTime",caption="Statistic about \\textbf{time when found optimal solution} needed for heurstic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quarta tabella: nIter
    results = []    
    for i, df in enumerate(dfs):
        for stats in obtainStatsSummary(df, "nIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "nIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC):
        for stats in obtainStatsSummary(df, "nIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:nIter",caption="Statistic about \\textbf{total number of iterations} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quinta tabella: optIter
    results = []    
    for i, df in enumerate(dfs):
        for stats in obtainStatsSummary(df, "optIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "optIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC):
        for stats in obtainStatsSummary(df, "optIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:optIter",caption="Statistic about \\textbf{iteration when it's found the best solution} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)
    f.write("\\end{document}")

# %%
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/times/SummaryTables_Greater.tex", "w") as f:
    f.write("\\begin{document}\n")

    #prima tabella: opt
    
    results = []
    for i, df in enumerate(dfs_G):
        #def obtainStatsSummary(filtered_merged, columnName, AP=False, NC=False):
        for stats in obtainStatsSummary(df, "opt"):
            results.append(stats)
    for i, df in enumerate(dfsAP_G):
        for stats in obtainStatsSummary(df, "opt",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC_G):
        for stats in obtainStatsSummary(df, "opt",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:results",caption="Statistics about \\textbf{objective function value} obtained from heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #seconda tabella: totalTime

    results = []
    for i, df in enumerate(dfs_G):
        for stats in obtainStatsSummary(df, "totalTime"):   
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "totalTime",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC_G):
        for stats in obtainStatsSummary(df, "totalTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:totalTime",caption="Statistic about \\textbf{total Time} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #terza tabella: bestTime
    results = []
    for i, df in enumerate(dfs_G):
        for stats in obtainStatsSummary(df, "bestTime"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_G):
        for stats in obtainStatsSummary(df, "bestTime",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_G):
        for stats in obtainStatsSummary(df, "bestTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:bestTime",caption="Statistic about \\textbf{time when found optimal solution} needed for heurstic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quarta tabella: nIter
    results = []    
    for i, df in enumerate(dfs_G):
        for stats in obtainStatsSummary(df, "nIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_G):
        for stats in obtainStatsSummary(df, "nIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_G):
        for stats in obtainStatsSummary(df, "nIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:nIter",caption="Statistic about \\textbf{total number of iterations} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quinta tabella: optIter
    results = []    
    for i, df in enumerate(dfs_G):
        for stats in obtainStatsSummary(df, "optIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_G):
        for stats in obtainStatsSummary(df, "optIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_G):
        for stats in obtainStatsSummary(df, "optIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:optIter",caption="Statistic about \\textbf{iteration when it's found the best solution} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)
    f.write("\\end{document}")

# %%
with open("/home/magi/UAMdeconflictionMasterThesis/risultati/afterThesis/heuristic/times/SummaryTables_Smaller.tex", "w") as f:
    f.write("\\begin{document}\n")

    #prima tabella: opt
    
    results = []
    for i, df in enumerate(dfs_S):
        #def obtainStatsSummary(filtered_merged, columnName, AP=False, NC=False):
        for stats in obtainStatsSummary(df, "opt"):
            results.append(stats)
    for i, df in enumerate(dfsAP_S):
        for stats in obtainStatsSummary(df, "opt",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC_S):
        for stats in obtainStatsSummary(df, "opt",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:results",caption="Statistics about \\textbf{objective function value} obtained from heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #seconda tabella: totalTime

    results = []
    for i, df in enumerate(dfs_S):
        for stats in obtainStatsSummary(df, "totalTime"):   
            results.append(stats)    
    for i, df in enumerate(dfsAP):
        for stats in obtainStatsSummary(df, "totalTime",AP=True):
            results.append(stats)
    for i, df in enumerate(dfsNC_S):
        for stats in obtainStatsSummary(df, "totalTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:totalTime",caption="Statistic about \\textbf{total Time} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #terza tabella: bestTime
    results = []
    for i, df in enumerate(dfs_S):
        for stats in obtainStatsSummary(df, "bestTime"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_S):
        for stats in obtainStatsSummary(df, "bestTime",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_S):
        for stats in obtainStatsSummary(df, "bestTime",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:bestTime",caption="Statistic about \\textbf{time when found optimal solution} needed for heurstic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quarta tabella: nIter
    results = []    
    for i, df in enumerate(dfs_S):
        for stats in obtainStatsSummary(df, "nIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_S):
        for stats in obtainStatsSummary(df, "nIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_S):
        for stats in obtainStatsSummary(df, "nIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:nIter",caption="Statistic about \\textbf{total number of iterations} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)

    #quinta tabella: optIter
    results = []    
    for i, df in enumerate(dfs_S):
        for stats in obtainStatsSummary(df, "optIter"):
            results.append(stats)    
    for i, df in enumerate(dfsAP_S):
        for stats in obtainStatsSummary(df, "optIter",AP=True):
            results.append(stats)    
    for i, df in enumerate(dfsNC_S):
        for stats in obtainStatsSummary(df, "optIter",NC=True):
            results.append(stats)

    latex_table = pd.DataFrame(results).to_latex(index=False, longtable=True, column_format="|l|r|r|r|r|r|r|",label="table:heuristic:optIter",caption="Statistic about \\textbf{iteration when it's found the best solution} needed for heuristic")
    latex_table = latex_table.replace(r'\toprule', "").replace(r'\midrule', "").replace(r'\bottomrule', "").replace(r'\\',r'\\ \hline')
    f.write(latex_table)
    f.write("\\end{document}")

# %% [markdown]
# ## Generating pictures
#
# TODO : undestand which picture we should create

# %% [markdown]
# ### Comparison between greater and smaller

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Set style
sns.set_style("whitegrid")

def plot_general_overview(datasets, names, metric='totalTime', title_suffix=''):
    """Plots distribution of a metric across multiple datasets"""
    plt.figure(figsize=(15, 6))
    
    data_to_plot = []
    labels = []
    
    for df, name in zip(datasets, names):
        # Filter valid data
        if metric in df.columns:
            valid_data = df[np.isfinite(df[metric])][metric]
            if len(valid_data) > 0:
                data_to_plot.append(valid_data)
                labels.append(name)
    
    # Boxplot
    plt.boxplot(data_to_plot, labels=labels, showmeans=True)
    plt.title(f'Distribution of {metric} {title_suffix}', fontsize=14)
    plt.ylabel(metric)
    plt.grid(True, alpha=0.3)
    plt.yscale('log') # Log scale often helps with time/opt differences
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# 1. General Overview of Time and Results
print("=== General Overview: Normal vs Smaller vs Greater ===")

# Prepare lists
dfs_dd = [pdDD, pdDD_Smaller, pdDD_Greater]
names_dd = ['DD Normal', 'DD Smaller', 'DD Greater']

dfs_ap = [pdAP, pdAP_Smaller, pdAP_Greater]
names_ap = ['AP Normal', 'AP Smaller', 'AP Greater']

dfs_nc = [pdNC, pdNC_Smaller, pdNC_Greater]
names_nc = ['NC Normal', 'NC Smaller', 'NC Greater']

# Plot Total Time
plot_general_overview(dfs_dd + dfs_ap + dfs_nc, names_dd + names_ap + names_nc, 'totalTime', '- All Datasets')

# Plot Optimization Value
plot_general_overview(dfs_dd + dfs_ap + dfs_nc, names_dd + names_ap + names_nc, 'opt', '- All Datasets')


# 2. Detailed Comparison: Smaller vs Greater
print("\n=== Detailed Comparison: Smaller vs Greater ===")

def compare_smaller_greater_detailed(df_smaller, df_greater, method_name):
    # Prepare data
    df_s = df_smaller.copy()
    df_s['Size'] = 'Smaller'
    df_g = df_greater.copy()
    df_g['Size'] = 'Greater'
    
    combined = pd.concat([df_s, df_g], ignore_index=True)
    
    # Filter
    combined = combined[np.isfinite(combined['opt']) & np.isfinite(combined['totalTime'])]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # Total Time
    sns.violinplot(data=combined, x='Size', y='totalTime', ax=axes[0], palette='muted', inner='quartile')
    axes[0].set_title(f'{method_name}: Total Time Distribution')
    axes[0].set_ylabel('Time (s)')
    
    # Opt
    sns.boxplot(data=combined, x='Size', y='opt', ax=axes[1], palette='muted')
    axes[1].set_title(f'{method_name}: Objective Value Distribution')
    axes[1].set_ylabel('Objective Value')
    axes[1].set_yscale('log')
    
    plt.suptitle(f'Comparison: {method_name}', fontsize=16)
    plt.tight_layout()
    plt.show()
    
    # Summary Table
    summary = combined.groupby('Size')[['totalTime', 'opt']].agg(['mean', 'median', 'std', 'count'])
    print(f"\nStats for {method_name}:")
    display(summary)

# Run comparisons
compare_smaller_greater_detailed(pdDD_Smaller, pdDD_Greater, "Delay & Drift (DD)")
compare_smaller_greater_detailed(pdAP_Smaller, pdAP_Greater, "High Priority (AP)")
compare_smaller_greater_detailed(pdNC_Smaller, pdNC_Greater, "Non-Collaborative Intruder(NC)")
# Out:
# === General Overview: Normal vs Smaller vs Greater ===
# === Detailed Comparison: Smaller vs Greater ===
# Stats for Delay & Drift (DD):
#          totalTime                                     opt            \
#               mean     median         std  count      mean    median
# Size
# Greater  42.743466  10.274325  111.376549  17607  7.082971  4.288221
# Smaller  46.573517  10.239071  118.962574  17770  7.588435  4.288221
#
#
#                std  count
# Size
# Greater  14.104676  17607
# Smaller  15.945626  17770
# Stats for High Priority (AP):
#          totalTime                                       opt               \
#               mean     median         std count         mean       median
# Size
# Greater  71.675764  18.035847  146.213192  5830  1048.451389  1000.026316
# Smaller  94.260235  19.173676  176.549694  5882  1048.878706  1000.578947
#
#
#                  std count
# Size
# Greater  1687.691540  5830
# Smaller  1674.712282  5882
# ...

# %% [markdown]
# ### Comparison chaning gapUnf and alpha

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set plot style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (14, 10)

# Function to analyze the effect of alpha and gapUnf parameters
def analyze_parameters_effect(df, dataset_name, metric='opt'):
    """Visualize how results change as alpha and gapUnf vary"""
    
    # Remove infinite values
    df_clean = df[np.isfinite(df[metric])].copy()
    
    # Create figure with 4 subplots
    fig = plt.figure(figsize=(16, 12))
    
    # 1. Heatmap - Average results for each combination
    ax1 = plt.subplot(2, 2, 1)
    pivot_mean = df_clean.groupby(['alpha', 'gapUnf'])[metric].mean().unstack()
    sns.heatmap(pivot_mean, annot=True, fmt='.2f', cmap='RdYlGn_r', ax=ax1, cbar_kws={'label': f'Average {metric}'})
    ax1.set_title(f'Heatmap: Average {metric} for alpha and gapUnf', fontsize=12, fontweight='bold')
    ax1.set_xlabel('gapUnf', fontsize=11)
    ax1.set_ylabel('alpha', fontsize=11)
    
    # 2. Line plot - Effect of alpha for each gapUnf
    ax2 = plt.subplot(2, 2, 2)
    for gapunf_val in sorted(df_clean['gapUnf'].unique()):
        subset = df_clean[df_clean['gapUnf'] == gapunf_val]
        means = subset.groupby('alpha')[metric].mean()
        ax2.plot(means.index, means.values, marker='o', label=f'gapUnf={gapunf_val}', linewidth=2, markersize=8)
    ax2.set_xlabel('alpha', fontsize=11)
    ax2.set_ylabel(f'Average {metric}', fontsize=11)
    ax2.set_title(f'Effect of alpha on {metric}', fontsize=12, fontweight='bold')
    ax2.legend(title='gapUnf', fontsize=9)
    ax2.grid(True, alpha=0.3)
    
    # 3. Line plot - Effect of gapUnf for each alpha
    ax3 = plt.subplot(2, 2, 3)
    for alpha_val in sorted(df_clean['alpha'].unique()):
        subset = df_clean[df_clean['alpha'] == alpha_val]
        means = subset.groupby('gapUnf')[metric].mean()
        ax3.plot(means.index, means.values, marker='s', label=f'alpha={alpha_val}', linewidth=2, markersize=8)
    ax3.set_xlabel('gapUnf', fontsize=11)
    ax3.set_xticks(sorted(df_clean['gapUnf'].unique()))
    ax3.set_ylabel(f'Average {metric}', fontsize=11)
    ax3.set_title(f'Effect of gapUnf on {metric}', fontsize=12, fontweight='bold')
    ax3.legend(title='alpha', fontsize=9)
    ax3.grid(True, alpha=0.3)
    
    # 4. Boxplot - Distribution for parameter combinations
    ax4 = plt.subplot(2, 2, 4)
    df_clean['params'] = 'α=' + df_clean['alpha'].astype(str) + ', gap=' + df_clean['gapUnf'].astype(str)
    param_order = sorted(df_clean['params'].unique(), key=lambda x: (int(x.split('α=')[1].split(',')[0]), int(x.split('gap=')[1])))
    sns.boxplot(data=df_clean, x='params', y=metric, order=param_order, ax=ax4, palette='Set2')
    ax4.set_xlabel('Parameter Combination', fontsize=11)
    ax4.set_ylabel(metric, fontsize=11)
    ax4.set_title(f'{metric} Distribution by Parameter Combination', fontsize=12, fontweight='bold')
    ax4.tick_params(axis='x', rotation=45, labelsize=8)
    
    plt.suptitle(f'{dataset_name} - Parameter Analysis: alpha and gapUnf', fontsize=14, fontweight='bold', y=0.995)
    plt.tight_layout()
    
    # Display the plot
    plt.show()
    
    # Print summary statistics
    print(f"\n{'='*80}")
    print(f"SUMMARY STATISTICS: {dataset_name} - {metric}")
    print(f"{'='*80}\n")
    
    # Table with statistics for each combination
    summary_table = df_clean.groupby(['alpha', 'gapUnf'])[metric].agg(['mean', 'std', 'min', 'max', 'count'])
    summary_table = summary_table.round(2)
    print("Mean, standard deviation, min, max, and count for each combination:")
    display(summary_table)
    
    # Best combination
    best_idx = summary_table['mean'].idxmin()
    print(f"\n✓ Best combination (minimum {metric}): alpha={best_idx[0]}, gapUnf={best_idx[1]}")
    print(f"  Average value: {summary_table.loc[best_idx, 'mean']:.2f} ± {summary_table.loc[best_idx, 'std']:.2f}")
    
    # Worst combination
    worst_idx = summary_table['mean'].idxmax()
    print(f"\n✗ Worst combination (maximum {metric}): alpha={worst_idx[0]}, gapUnf={worst_idx[1]}")
    print(f"  Average value: {summary_table.loc[worst_idx, 'mean']:.2f} ± {summary_table.loc[worst_idx, 'std']:.2f}")
    
    print(f"\n{'='*80}\n")
    
    return summary_table

# USAGE EXAMPLES
# Analyze the effect of alpha and gapUnf on optimal value for the complete dataset
print("Analysis for Complete Dataset - 3 Delays (DD)")
analyze_parameters_effect(pdDD, 'Complete_Dataset_DD', metric='opt')

# Analyze the effect on total time
print("\n\nTotal Time Analysis for Complete Dataset (DD)")
analyze_parameters_effect(pdDD, 'Complete_Dataset_DD', metric='totalTime')

# You can repeat for other datasets by changing the dataframe:
# analyze_parameters_effect(df_grid01, 'grid01_DD', metric='opt')
# analyze_parameters_effect(df_mpAP, 'metroplex_AP', metric='opt')
# analyze_parameters_effect(df_G_air01, 'airport01_Greater', metric='totalTime')
# Out:
# Analysis for Complete Dataset - 3 Delays (DD)
# ...
# SUMMARY STATISTICS: Complete_Dataset_DD - opt
# ...
#
# Mean, standard deviation, min, max, and count for each combination:
#               mean    std  min     max  count
# alpha gapUnf
# 4     1       5.85   4.98  0.1   33.90    897
#       2       8.91  21.81  0.1  237.40    888
#       5       8.33  22.20  0.1  341.41    888
#       10      7.06  19.11  0.1  391.72    875
# 9     1       6.24   7.63  0.1  132.49    896
#       2       8.05  19.19  0.1  299.42    888
#       5       7.39  19.74  0.1  305.88    880
#       10      7.58  17.10  0.1  225.97    878
# 16    1       6.26   7.66  0.1  132.49    896
#       2       7.44  15.02  0.1  206.03    888
#       5       7.49  21.03  0.1  328.80    878
#       10      7.60  15.56  0.1  190.25    879
# 25    1       6.27   7.68  0.1  132.49    894
#       2       7.28  15.56  0.1  284.05    884
#       5       7.94  27.36  0.1  539.31    874
#       10      7.67  15.96  0.1  190.25    876
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Set style
sns.set_style("whitegrid")

def plot_general_overview(datasets, names, metric='totalTime', title_suffix=''):
    """Plots distribution of a metric across multiple datasets"""
    plt.figure(figsize=(15, 6))
    
    data_to_plot = []
    labels = []
    
    for df, name in zip(datasets, names):
        # Filter valid data
        if metric in df.columns:
            valid_data = df[np.isfinite(df[metric])][metric]
            if len(valid_data) > 0:
                data_to_plot.append(valid_data)
                labels.append(name)
    
    # Boxplot
    plt.boxplot(data_to_plot, labels=labels, showmeans=True)
    plt.title(f'Distribution of {metric} {title_suffix}', fontsize=14)
    plt.ylabel(metric)
    plt.grid(True, alpha=0.3)
    plt.yscale('log') # Log scale often helps with time/opt differences
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()

# 1. General Overview of Time and Results
print("=== General Overview: Normal vs Smaller vs Greater ===")

# Prepare lists
dfs_dd = [pdDD, pdDD_Smaller, pdDD_Greater]
names_dd = ['DD Normal', 'DD Smaller', 'DD Greater']

dfs_ap = [pdAP, pdAP_Smaller, pdAP_Greater]
names_ap = ['AP Normal', 'AP Smaller', 'AP Greater']

dfs_nc = [pdNC, pdNC_Smaller, pdNC_Greater]
names_nc = ['NC Normal', 'NC Smaller', 'NC Greater']

# Plot Total Time
plot_general_overview(dfs_dd + dfs_ap + dfs_nc, names_dd + names_ap + names_nc, 'totalTime', '- All Datasets')

# Plot Optimization Value
plot_general_overview(dfs_dd + dfs_ap + dfs_nc, names_dd + names_ap + names_nc, 'opt', '- All Datasets')


# 2. Detailed Comparison: Smaller vs Greater
print("\n=== Detailed Comparison: Smaller vs Greater ===")

def compare_smaller_greater_detailed(df_smaller, df_greater, method_name):
    # Prepare data
    df_s = df_smaller.copy()
    df_s['Size'] = 'Smaller'
    df_g = df_greater.copy()
    df_g['Size'] = 'Greater'
    
    combined = pd.concat([df_s, df_g], ignore_index=True)
    
    # Filter
    combined = combined[np.isfinite(combined['opt']) & np.isfinite(combined['totalTime'])]
    
    fig, axes = plt.subplots(1, 2, figsize=(16, 6))
    
    # Total Time
    sns.violinplot(data=combined, x='Size', y='totalTime', ax=axes[0], palette='muted', inner='quartile')
    axes[0].set_title(f'{method_name}: Total Time Distribution')
    axes[0].set_ylabel('Time (s)')
    
    # Opt
    sns.boxplot(data=combined, x='Size', y='opt', ax=axes[1], palette='muted')
    axes[1].set_title(f'{method_name}: Objective Value Distribution')
    axes[1].set_ylabel('Objective Value')
    axes[1].set_yscale('log')
    
    plt.suptitle(f'Comparison: {method_name}', fontsize=16)
    plt.tight_layout()
    plt.show()
    
    # Summary Table
    summary = combined.groupby('Size')[['totalTime', 'opt']].agg(['mean', 'median', 'std', 'count'])
    print(f"\nStats for {method_name}:")
    display(summary)

# Run comparisons
compare_smaller_greater_detailed(pdDD_Smaller, pdDD_Greater, "Delay & Drift (DD)")
compare_smaller_greater_detailed(pdAP_Smaller, pdAP_Greater, "All Path (AP)")
compare_smaller_greater_detailed(pdNC_Smaller, pdNC_Greater, "Node Connection (NC)")
# Out:
# === General Overview: Normal vs Smaller vs Greater ===
# === Detailed Comparison: Smaller vs Greater ===
# Stats for Delay & Drift (DD):
#          totalTime                                     opt            \
#               mean     median         std  count      mean    median
# Size
# Greater  42.743466  10.274325  111.376549  17607  7.082971  4.288221
# Smaller  46.573517  10.239071  118.962574  17770  7.588435  4.288221
#
#
#                std  count
# Size
# Greater  14.104676  17607
# Smaller  15.945626  17770
# Stats for All Path (AP):
#          totalTime                                       opt               \
#               mean     median         std count         mean       median
# Size
# Greater  71.675764  18.035847  146.213192  5830  1048.451389  1000.026316
# Smaller  94.260235  19.173676  176.549694  5882  1048.878706  1000.578947
#
#
#                  std count
# Size
# Greater  1687.691540  5830
# Smaller  1674.712282  5882
# ...
